# %% [markdown]
# # Do it yourself
#
# Try **currency type** datastructure to perform your financial analyisis on exchange rates.

# %%
# %matplotlib inline

from forex_data import *

import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Select the exchage rate and time interval
#
# Note: Consider that the empirical data is obtained from Yahoo!'s databases.
#
# In the next cell, change:
# * units
# * base
# * t0
# * tf

# %%
# Initialize currency

a = currency(units='EUR', base = 'USD', t0 = '2015/01/01', tf = '2016/01/01')
a.fill()

# %%
# Visualization
a.prices.plot(); a.returns.plot()

# %% [markdown]
# ## Monte Carlo Simulation
#
# Perform a basic Monte Carlo Simulation

# %%
a.montecarlo_simul(periods = 50, tr_y = 40)
# Out:
# The expected value of the exchange rate in 50 periods is: 0.9388621502588483
# 0.93886215025884834

# %% [markdown]
# ## Do more
#
# Please, enjoy yourself.

# %%
# Write your code here!

# %%
# And here

# %%
# ...
